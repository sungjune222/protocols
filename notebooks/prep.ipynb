# %% [markdown]
# kernel : Python (Pixi)

# %% [markdown]
# #### Standardizing Heterogeneous gene expression Data Formats
#
# Public datasets provided through GEO (Gene Expression Omnibus) and SCA (Single Cell Atlas) are uploaded by individual researchers, each using data structures and file formats that are most convenient for their own experimental workflows.
# As a result, gene expression data lack any consistent or unified format across studies.
# If such heterogeneous data are used directly without prior standardization, it can lead to serious downstream problems, including parsing errors, incorrect sample-to-metadata mappings, incompatible matrix structures, and irreproducible analysis results.
# This standardization step ensures structural consistency, improves pipeline robustness, and minimizes technical variability unrelated to the underlying biological signals.

# %%
# %load_ext autoreload
# %autoreload 2

# %% Environment Setup: Python libraries, GPU settings, and R integration
import gc
import os
import anndata2ri
import pandas as pd
import scanpy as sc
from anndata import AnnData
from scipy import sparse
from scipy.sparse import csr_matrix, csc_matrix
from pipeline.utils.env import find_env_dir

raw_data_dir = find_env_dir("RAW_DATA")
pre_h5ad_dir = find_env_dir("PRE_H5AD")
# Out:
# Error importing in API mode: ImportError('libopenblas.so.0: cannot open shared object file: No such file or directory')
# Trying to import in ABI mode.

# %% [markdown]
# Currently supports `.mtx`, `.rds`, `.csv`, and `.gz`-compressed versions

# %%
# Loads single file based on its format
def load_single_file(path: str) -> AnnData:
    name = path.split("/")[-1].lower()

    # Dispatcher currently supports gzipped .rds and .csv files
    if name.endswith(".rds.gz"):
        return load_rds_data(path, gz=True)
    elif name.endswith(".rds"):
        return load_rds_data(path, gz=False)
    elif name.endswith(".csv.gz") or name.endswith(".csv"):
        return load_csv_data(path)
    else:
        raise ValueError(
        f"Unsupported file type: '{name}'. "
        "This appears to be a new file type, so a new parsing logic is required."
    )

# Loads RDS.gz data
def load_rds_data(rds_path: str, gz: bool) -> AnnData:
    from rpy2.robjects import r
    from rpy2.robjects.conversion import localconverter
    from rpy2.robjects.packages import importr

    # Activate automatic conversion from R Seurat objects to Python AnnData objects
    importr("base")
    importr("Matrix")
    importr("Seurat")
    importr("SingleCellExperiment")
    
    if gz:
        read_cmd = f'readRDS(gzcon(gzfile("{rds_path}", "rb")))'
    else:
        read_cmd = f'readRDS("{rds_path}")'

    rcode = f"""
    obj <- {read_cmd}
    if (inherits(obj, "Seurat")) {{
        obj <- as.SingleCellExperiment(obj)
    }}
    assay(obj, "counts") <- as(assay(obj, "counts"), "dgCMatrix")
    # Overwrite 'X' assay with 'counts' assay
    assay(obj, "X") <- assay(obj, "counts")
    obj
    """
    with localconverter(anndata2ri.converter):
        adata = r(rcode)
        r("if (exists('obj')) rm(obj)")
        r("gc()")

    if not isinstance(adata, AnnData):
        raise ValueError("Resulting object is not an AnnData")

    adata.layers.pop("counts", None)
    if not isinstance(adata.X, csr_matrix):
        adata.X = csr_matrix(adata.X)
    
    # Multidimensional representations (obsm, varm, layers) are intentionally cleared at this stage,
    # since integrated multi-modal / multi-dimensional analyses will be performed after dataset integration, 
    # overwriting any existing representations.
    adata.obsm = {}
    adata.varm = {}
    adata.layers = {}
    gc.collect()

    adata.obs["series"] = rds_path.split("/")[-1].split("_")[0]
    adata.obs["batch"] = "not set"
    return adata


# Loads CSV.gz data
def load_csv_data(csv_path: str) -> AnnData:
    adata: AnnData = sc.read_csv(csv_path).T

    # Converting to csr_matrix for memory efficiency and speed
    if not isinstance(adata.X, csr_matrix):
        adata.X = csr_matrix(adata.X)
    adata.obs["series"] = csv_path.split("/")[-1].split("_")[0]
    adata.obs["batch"] = "not set"
    return adata

# Loads 10x format data
def load_10x_data(mtx_file: str, barcodes_file: str, features_file: str, series: str) -> AnnData:
    adata: AnnData = sc.read_mtx(mtx_file).T

    with open(barcodes_file, "r") as f:
        barcodes = [line.strip().split("\t")[0] for line in f]
    with open(features_file, "r") as f:
        genes = [line.strip().split("\t")[0] for line in f]
    adata.obs_names = barcodes
    adata.var_names = genes

    # Converting to csr_matrix for memory efficiency and speed
    if not isinstance(adata.X, csr_matrix):
        adata.X = csr_matrix(adata.X)
    adata.obs["series"] = series
    adata.obs["batch"] = "not set"
    return adata

def load_mtx(mtx_file: str, col_data_file: str, row_data_file: str, series: str) -> AnnData:
    adata: AnnData = sc.read_mtx(mtx_file).T

    obs_df = pd.read_csv(col_data_file, sep=",", index_col=2)
    var_df = pd.read_csv(row_data_file, sep=",", index_col=0)
    adata.obs = obs_df
    adata.var = var_df

    # Converting to csr_matrix for memory efficiency and speed
    if not isinstance(adata.X, csr_matrix):
        adata.X = csr_matrix(adata.X)

    adata.obs["series"] = series
    adata.obs["batch"] = "not set"
    return adata

def load_dense_text_matrix(matrix_file: str, annotation_file: str, series: str) -> AnnData:
    meta = pd.read_csv(annotation_file, sep="\t", index_col=0)

    CHUNK_SIZE = 4000
    sparse_chunks = []
    gene_names = []
    cell_names = None
    for i, chunk in enumerate(pd.read_csv(matrix_file, index_col=0, chunksize=CHUNK_SIZE)):
        if i == 0:
            cell_names = chunk.columns.astype(str)
        gene_names.extend(chunk.index.astype(str))
        sparse_chunks.append(csc_matrix(chunk.values))
        print(f"Processing Chunk {i}")

    X_sparse_genes_by_cells = sparse.vstack(sparse_chunks)
    X_sparse_genes_by_cells = X_sparse_genes_by_cells.transpose().tocsr()
    adata = sc.AnnData(X=X_sparse_genes_by_cells)

    adata.obs_names = cell_names # type: ignore
    adata.var_names = gene_names
    
    common_cells = adata.obs_names.intersection(meta.index)
    adata = adata[common_cells].copy()
    meta = meta.loc[common_cells]
    
    adata.obs = meta
    adata.obs["series"] = series
    adata.obs["batch"] = "not set"
    return adata

# %% [markdown]
# Replace `FILE` with each of your own input files and set `SAVE_FILE_NAME` accordingly
# - For single files (ex. .rds, .csv, ...): Run first cell
# - For 10x format (.mtx / barcodes.tsv, features.tsv): Run second cell
# - For .mtx format with separate annotation files: Run third cell
# - For dense text matrix formats (matrix.txt / annotation.txt): Run fourth cell
#
# Repeat the entire workflow below for each dataset

# %%
FILE = "GSE232703_final_duodenum.rds.gz"
SAVE_FILE_NAME = "GSE232703_duodenum.h5ad"
adata = load_single_file(os.path.join(raw_data_dir, FILE))
adata.obs.head() #type: ignore
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#                                 orig.ident  nCount_RNA  nFeature_RNA  \
# GGTAATCAGGCACAAC-1_1_1  vehicle_duo_female       56193          7741
# CCAATGACAATTTCCT-1_1_1  vehicle_duo_female       60236          7566
# AGGACGACACAGAAGC-1_1_1  vehicle_duo_female       43884          7484
# CCTCCTCGTAGCTTTG-1_1_1  vehicle_duo_female       36649          7895
# ACTTATCGTTACACTG-1_1_1  vehicle_duo_female       39911          7433
#
#                         percent.mt  nCount_SCT  nFeature_SCT  SCT_snn_res.1  \
# GGTAATCAGGCACAAC-1_1_1    0.554828        2286           892             19
# CCAATGACAATTTCCT-1_1_1    1.516347        3106           839             20
# AGGACGACACAGAAGC-1_1_1    1.143627        2356          1004             15
# CCTCCTCGTAGCTTTG-1_1_1    0.520177        1899           487              8
# ACTTATCGTTACACTG-1_1_1    0.583875        2500           877              4
#
#                        seurat_clusters  SCT_snn_res.0.5              celltype  \
# GGTAATCAGGCACAAC-1_1_1              37               22           epithelial5
# CCAATGACAATTTCCT-1_1_1              34               10  gastric_surface_cell
# AGGACGACACAGAAGC-1_1_1              21                5           epithelial3
# CCTCCTCGTAGCTTTG-1_1_1              19                1           enterocyte4
# ACTTATCGTTACACTG-1_1_1              23               17                +4cell
#
#                         ... broadidentity SCT_snn_res.2             annotated  \
# GGTAATCAGGCACAAC-1_1_1  ...           EEC            37                   EEC
# CCAATGACAATTTCCT-1_1_1  ...        paneth            34  gastric_surface_cell
# AGGACGACACAGAAGC-1_1_1  ...    epithelial            21           epithelial3
# CCTCCTCGTAGCTTTG-1_1_1  ...    epithelial            19           enterocyte4
# ACTTATCGTTACACTG-1_1_1  ...        +4cell            23                +4cell
#
#                               broad_identity   S.Score  G2M.Score      Phase  \
# GGTAATCAGGCACAAC-1_1_1                   EEC -0.005940  -0.012746         G1
# CCAATGACAATTTCCT-1_1_1  gastric_surface_cell -0.037099  -0.039733         G1
# AGGACGACACAGAAGC-1_1_1            epithelial -0.008745  -0.025641         G1
# CCTCCTCGTAGCTTTG-1_1_1            enterocyte  0.000000   0.000000  Undecided
# ACTTATCGTTACACTG-1_1_1                +4cell  0.000000  -0.007995          S
#
#                                        ident     series    batch
# GGTAATCAGGCACAAC-1_1_1           epithelial5  GSE232703  not set
# CCAATGACAATTTCCT-1_1_1  gastric_surface_cell  GSE232703  not set
# AGGACGACACAGAAGC-1_1_1           epithelial3  GSE232703  not set
# CCTCCTCGTAGCTTTG-1_1_1           enterocyte4  GSE232703  not set
# ACTTATCGTTACACTG-1_1_1                +4cell  GSE232703  not set
#
# [5 rows x 34 columns]

# %%
MTX_FILE = "SCP1038_mli.matrix.mtx"
BARCODES_FILE = "SCP1038_mli.barcodes.tsv"
FEATURES_FILE = "SCP1038_mli.genes.tsv"
SERIES = "SCP1038"
SAVE_FILE_NAME = SERIES + ".h5ad"


adata = load_10x_data(
    os.path.join(raw_data_dir, MTX_FILE),
    os.path.join(raw_data_dir, BARCODES_FILE),
    os.path.join(raw_data_dir, FEATURES_FILE),
    series = SERIES
)
adata.obs.head() #type: ignore

# %%
MTX_FILE = "ms_lesions_snRNAseq_cleaned_counts_matrix_2023-09-12.mtx.gz"
COL_DATA_FILE = "ms_lesions_snRNAseq_col_data_2023-09-12.txt.gz"
ROW_DATA_FILE = "ms_lesions_snRNAseq_row_data_2023-09-12.txt.gz"
SERIES = "macnair"
SAVE_FILE_NAME = SERIES + ".h5ad"

data_dir = os.path.join(raw_data_dir, "macnair")

adata = load_mtx(
    os.path.join(data_dir, MTX_FILE),
    os.path.join(data_dir, COL_DATA_FILE),
    os.path.join(data_dir, ROW_DATA_FILE),
    series = SERIES
)
adata.obs.head() #type: ignore
# Out:
#                                  sample_id_anon individual_id_anon  \
# cell_id
# Ind65-Sample1:AAACCCATCACGAGGA-1  Ind65-Sample1              Ind65
# Ind65-Sample1:AAACGAACATTGACAC-1  Ind65-Sample1              Ind65
# Ind65-Sample1:AAACGAATCGCCAATA-1  Ind65-Sample1              Ind65
# Ind65-Sample1:AAACGCTCAATTCACG-1  Ind65-Sample1              Ind65
# Ind65-Sample1:AAACGCTGTAAGTTGA-1  Ind65-Sample1              Ind65
#
#                                         type_fine          type_broad  \
# cell_id
# Ind65-Sample1:AAACCCATCACGAGGA-1          Astro_A          Astrocytes
# Ind65-Sample1:AAACGAACATTGACAC-1         Exc_CUX2  Excitatory neurons
# Ind65-Sample1:AAACGAATCGCCAATA-1  Exc_CUX2_RORB_A  Excitatory neurons
# Ind65-Sample1:AAACGCTCAATTCACG-1            OPC_2         OPCs + COPs
# Ind65-Sample1:AAACGCTGTAAGTTGA-1         Pericyte         Endo + Peri
#
#                                         cluster_zoom  exclude_pseudobulk  \
# cell_id
# Ind65-Sample1:AAACCCATCACGAGGA-1     astrocytes-cl02               False
# Ind65-Sample1:AAACGAACATTGACAC-1          excit-cl01               False
# Ind65-Sample1:AAACGAATCGCCAATA-1          excit-cl02               False
# Ind65-Sample1:AAACGCTCAATTCACG-1      oligo_opc-cl08               False
# Ind65-Sample1:AAACGCTGTAAGTTGA-1  imm_endo_peri-cl02               False
#
#                                  cortical_layer  log10_counts  log10_feats  \
# cell_id
# Ind65-Sample1:AAACCCATCACGAGGA-1            NaN      3.151982     2.953760
# Ind65-Sample1:AAACGAACATTGACAC-1        Layer_2      3.848128     3.447313
# Ind65-Sample1:AAACGAATCGCCAATA-1        Layer_2      2.700704     2.633468
# Ind65-Sample1:AAACGCTCAATTCACG-1            NaN      2.723456     2.568202
# Ind65-Sample1:AAACGCTGTAAGTTGA-1            NaN      3.212454     3.047275
#
#                                   logit_mito  ...  \
# cell_id                                       ...
# Ind65-Sample1:AAACCCATCACGAGGA-1   -2.717851  ...
# Ind65-Sample1:AAACGAACATTGACAC-1   -2.493697  ...
# Ind65-Sample1:AAACGAATCGCCAATA-1   -5.117994  ...
# Ind65-Sample1:AAACGCTCAATTCACG-1   -3.766997  ...
# Ind65-Sample1:AAACGCTGTAAGTTGA-1   -3.249230  ...
#
#                                                                      cause_of_death  \
# cell_id
# Ind65-Sample1:AAACCCATCACGAGGA-1  heart diseas, myocardial infarction, coronary ...
# Ind65-Sample1:AAACGAACATTGACAC-1  heart diseas, myocardial infarction, coronary ...
# Ind65-Sample1:AAACGAATCGCCAATA-1  heart diseas, myocardial infarction, coronary ...
# Ind65-Sample1:AAACGCTCAATTCACG-1  heart diseas, myocardial infarction, coronary ...
# Ind65-Sample1:AAACGCTGTAAGTTGA-1  heart diseas, myocardial infarction, coronary ...
#
#                                   years_w_ms  pmi_minutes   smoker age_scale  \
# cell_id
# Ind65-Sample1:AAACCCATCACGAGGA-1         NaN         6180  unknown -1.347464
# Ind65-Sample1:AAACGAACATTGACAC-1         NaN         6180  unknown -1.347464
# Ind65-Sample1:AAACGAATCGCCAATA-1         NaN         6180  unknown -1.347464
# Ind65-Sample1:AAACGCTCAATTCACG-1         NaN         6180  unknown -1.347464
# Ind65-Sample1:AAACGCTGTAAGTTGA-1         NaN         6180  unknown -1.347464
#
#                                    age_cat   pmi_cat  pmi_cat2   series  \
# cell_id
# Ind65-Sample1:AAACCCATCACGAGGA-1  under_50  over_12H  over_12H  macnair
# Ind65-Sample1:AAACGAACATTGACAC-1  under_50  over_12H  over_12H  macnair
# Ind65-Sample1:AAACGAATCGCCAATA-1  under_50  over_12H  over_12H  macnair
# Ind65-Sample1:AAACGCTCAATTCACG-1  under_50  over_12H  over_12H  macnair
# Ind65-Sample1:AAACGCTGTAAGTTGA-1  under_50  over_12H  over_12H  macnair
#
#                                     batch
# cell_id
# Ind65-Sample1:AAACCCATCACGAGGA-1  not set
# Ind65-Sample1:AAACGAACATTGACAC-1  not set
# Ind65-Sample1:AAACGAATCGCCAATA-1  not set
# Ind65-Sample1:AAACGCTCAATTCACG-1  not set
# Ind65-Sample1:AAACGCTGTAAGTTGA-1  not set
#
# [5 rows x 30 columns]

# %%
adata = adata[adata.obs["exclude_pseudobulk"] == False].copy()

assert isinstance(adata.obs, pd.DataFrame)
adata.obs["celltype"] = adata.obs["type_broad"]
adata.obs["celltype_fine"] = adata.obs["type_fine"]
adata.obs["sample"] = adata.obs["sample_id_anon"]
adata.obs["batch"] = adata.obs["sample"]
adata.obs["lesion"] = adata.obs["lesion_type"]
adata.obs["pmi"] = adata.obs["pmi_cat2"]
adata.obs["source"] = adata.obs["sample_source"]
adata.obs["age"] = adata.obs["age_scale"]
adata.obs["sex"] = adata.obs["sex"]
adata.obs["diagnosis"] = adata.obs["diagnosis"]
adata.obs["matter"] = adata.obs["matter"]
adata.obs["pool"] = adata.obs["seq_pool"]
adata.obs["series"] = adata.obs["series"]
keep = ["celltype", "celltype_fine", "sample", "batch", "lesion", "pmi", "source", "age", "sex", "diagnosis", "matter", "pool", "series"]
adata.obs.drop(columns = [c for c in adata.obs.columns if c not in keep], inplace=True) #type: ignore

# %%
SERIES = "GSE180759"
MATRIX_FILE = "GSE180759_expression_matrix.csv.gz"
ANNOTATION_FILE = "GSE180759_annotation.txt.gz"
SAVE_FILE_NAME = SERIES + ".h5ad"

data_dir= os.path.join(raw_data_dir, "Absinta")

adata = load_dense_text_matrix(
    os.path.join(data_dir, MATRIX_FILE),
    os.path.join(data_dir, ANNOTATION_FILE),
    SERIES
)
adata.obs.head() #type: ignore
# Out:
# Processing Chunk 0
# Processing Chunk 1
# Processing Chunk 2
# Processing Chunk 3
# Processing Chunk 4
# Processing Chunk 5
# Processing Chunk 6
# Processing Chunk 7
#                    NBB_case                      pathology  seurat_cluster  \
# AAACCCAAGTGCAGCA-1   13_047  chronic_active_MS_lesion_edge               3
# AAACCCACAGTGGGTA-1   13_047  chronic_active_MS_lesion_edge               0
# AAACCCATCATCTACT-1   13_047  chronic_active_MS_lesion_edge               1
# AAACCCATCGAACGGA-1   13_047  chronic_active_MS_lesion_edge               1
# AAACCCATCTAGTGTG-1   13_047  chronic_active_MS_lesion_edge               0
#
#                            cell_type     series    batch
# AAACCCAAGTGCAGCA-1  oligodendrocytes  GSE180759  not set
# AAACCCACAGTGGGTA-1  oligodendrocytes  GSE180759  not set
# AAACCCATCATCTACT-1  oligodendrocytes  GSE180759  not set
# AAACCCATCGAACGGA-1  oligodendrocytes  GSE180759  not set
# AAACCCATCTAGTGTG-1  oligodendrocytes  GSE180759  not set

# %%
assert isinstance(adata.obs, pd.DataFrame)
adata.obs["celltype"] = adata.obs["cell_type"]
adata.obs["sample"] = adata.obs["NBB_case"]
adata.obs["batch"] = adata.obs["sample"]
adata.obs["annotation"] = adata.obs["pathology"]
keep = ["batch", "celltype", "sample", "series", "annotation"]
adata.obs.drop(columns = [c for c in adata.obs.columns if c not in keep], inplace=True) #type: ignore
# Out:
#                    NBB_case                      pathology  seurat_cluster  \
# AAACCCAAGTGCAGCA-1   13_047  chronic_active_MS_lesion_edge               3
# AAACCCACAGTGGGTA-1   13_047  chronic_active_MS_lesion_edge               0
# AAACCCATCATCTACT-1   13_047  chronic_active_MS_lesion_edge               1
# AAACCCATCGAACGGA-1   13_047  chronic_active_MS_lesion_edge               1
# AAACCCATCTAGTGTG-1   13_047  chronic_active_MS_lesion_edge               0
#
#                            cell_type     series   batch          celltype  \
# AAACCCAAGTGCAGCA-1  oligodendrocytes  GSE180759  13_047  oligodendrocytes
# AAACCCACAGTGGGTA-1  oligodendrocytes  GSE180759  13_047  oligodendrocytes
# AAACCCATCATCTACT-1  oligodendrocytes  GSE180759  13_047  oligodendrocytes
# AAACCCATCGAACGGA-1  oligodendrocytes  GSE180759  13_047  oligodendrocytes
# AAACCCATCTAGTGTG-1  oligodendrocytes  GSE180759  13_047  oligodendrocytes
#
#                     sample                     annotation
# AAACCCAAGTGCAGCA-1  13_047  chronic_active_MS_lesion_edge
# AAACCCACAGTGGGTA-1  13_047  chronic_active_MS_lesion_edge
# AAACCCATCATCTACT-1  13_047  chronic_active_MS_lesion_edge
# AAACCCATCGAACGGA-1  13_047  chronic_active_MS_lesion_edge
# AAACCCATCTAGTGTG-1  13_047  chronic_active_MS_lesion_edge

# %% [markdown]
# #### Reformat cell-level metadata to retain only the required information
# Modify, extend, or remove parts of the code as needed, since the exact structure and annotations differ across datasets.
# In practice, you will certainly need to modify this code to accommodate the specific structure and annotations of each dataset.

# %%
META_DATA_FILE = "SCP1038.meta.txt"
meta = pd.read_csv(os.path.join(raw_data_dir, META_DATA_FILE), sep="\t")
meta.set_index("NAME", inplace=True)

meta = meta[meta["Dataset"].fillna("").str.contains("all cells", case=False)]

assert isinstance(adata.obs, pd.DataFrame)
adata.obs = adata.obs.join(meta, how="left")

with open(os.path.join(raw_data_dir, "SCP1038_mli.glia.barcodes.tsv"), "r") as f:
    enteric_glia = [line.strip().split("\t")[0] for line in f]
with open(os.path.join(raw_data_dir, "SCP1038_mli.neur.barcodes.tsv"), "r") as f:
    enteric_neurons = [line.strip().split("\t")[0] for line in f]

adata.obs["celltype"] = "others"
adata.obs["celltype"].loc[adata.obs_names.isin(enteric_glia)] = "Enteric_Glia"
adata.obs["celltype"].loc[adata.obs_names.isin(enteric_neurons)] = "Enteric_Neurons"

adata.obs["sample"] = adata.obs["Unique_ID"]
adata.obs["batch"] = adata.obs["sample"]
adata.obs["doublet_batch"] = adata.obs["Overload"]
adata.obs["annotation"] = adata.obs["Annotation"]
keep = ["batch", "celltype", "sample", "series", "sex", "doublet_batch", "annotation"]
adata.obs.drop(columns = [c for c in adata.obs.columns if c not in keep], inplace=True) #type: ignore
# Out:
# /tmp/ipykernel_233337/1343514411.py:2: DtypeWarning: Columns (1,4,5,7,9,11,12,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv(os.path.join(raw_count_matrix_location, META_DATA_FILE), sep="\t")

# %%
adata.obs_keys()
# Out:
# /tmp/ipykernel_2848687/4173232095.py:1: FutureWarning: Use obs (e.g. `k in adata.obs` or `str(adata.obs.columns.tolist())`) instead of AnnData.obs_keys, AnnData.obs_keys is deprecated and will be removed in the future.
#   adata.obs_keys()
# ['NBB_case', 'pathology', 'seurat_cluster', 'cell_type', 'series', 'batch']

# %%
is_human = adata.obs["orig.ident"].str.contains("human", case=False)
adata = adata[~is_human].copy()

def parse_sex(s: str) -> str:
    s_low = s.lower()
    if "female" in s_low:
        return "female"
    elif "male" in s_low:
        return "male"
    return "unknown"
adata.obs["sex"] = adata.obs["orig.ident"].map(parse_sex).astype("category")

geo = adata.obs["series"].astype(str)

assert isinstance(adata.obs, pd.DataFrame)
adata.obs["sample"] = (geo + "-" + adata.obs["orig.ident"]).astype("category")
adata.obs["celltype"] = adata.obs["broadidentity"]
keep = ["celltype", "sample", "series", "sex", "batch"]
adata.obs.drop(columns = [c for c in adata.obs.columns if c not in keep], inplace=True) #type: ignore

# %% [markdown]
# Save the processed AnnData object as an `.h5ad` file and free the associated memory

# %%
adata.obs.index = adata.obs.index.astype(str)
adata.var.index = adata.var.index.astype(str)
adata.write_h5ad(os.path.join(pre_h5ad_dir, "macnair.h5ad"))
del adata
gc.collect()
# Out:
# 638
